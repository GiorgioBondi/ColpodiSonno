# %%
# %matplotlib inline
from pynq.pmods import Grove_IMU
from IPython import display
from ipywidgets import widgets
import numpy as np
import scipy.signal as signal
import time
import matplotlib.pyplot as plt


# initialize Grove IMU on PMOD 1 (JB) and grove id 4 (GR4).
# PMOD mapping is: PMOD 1 -> JB, PMOD 2 -> JC, PMOD 3 -> JD, PMOD 4 -> JE
# NOTE: only GR4 can be used for the Grove IMU
imu = Grove_IMU(1,4)

#empty lists creation
accX=list()
accY=list()
accZ=list()
pitch_l=list()

while (True):
        
        start=time.time()
        
        # get data from accelerometer
        accl = imu.get_accl()

        accX.append(accl[0])
        accY.append(accl[1])
        accZ.append(accl[2])
        
        #calculate pitch from accelerations
        argomento= accl[1]/np.sqrt(accl[0]*accl[0]*accl[1]*accl[1])
        pitch = np.arctan(argomento)
        pitch_l.append(pitch)
        
        time.sleep(0.1)
        
    except KeyboardInterrupt:
        # exit without showing errors if the stop button in Jupyter is pressed
        end=time.time()
        break

tc=(end-start)/len(accl[0]) #tempo di campionamento effettivo

#array creation from data-filled lists
accX_arr=np.array(accX)
accY_arr=np.array(accY)
accZ_arr=np.array(accZ)
pitch_arr=np.array(pitch_l)

np.savetxt("DataXmov.npy", accX_arr)
np.savetxt("DataYmov.npy", accY_arr)
np.savetxt("DataZmov.npy", accZ_arr)
np.savetxt("DataPmov.npy",pitch_arr)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

def individuaOutlier(data,t):
    
    movAvg=pd.Series(data).rolling(len(data)*t).mean()

    #calcolo della Standard Deviation per identificazione outlier
    movStd=pd.Series(data).rolling(len(data)*t).std()
    sec_outlier=list()
    cmp_outlier=list()
    for i in range(len(data)):
        if (abs(data[i]-movAvg[i])>2*movStd[i]):
            sec_outlier.append(i*t)
            cmp_outlier.append(i)

    print("Outlier presenti ai secondi:")
    print(sec_outlier)
    print("I campioni outlier sono")
    print(cmp_outlier)

    t=np.arange(0,len(data)*t,t)
    plt.figure(figsize=(10,10))
    plt.plot(t,data,color='g')
    plt.plot(t,movAvg,color='r')
    plt.show()
    
    return(cmp_outlier)

# %%
#In questa porzione di codice sto tagliuzzando i dati dell'accelerazioneZ per identificare dei picchi "standard" 
#da usare come riconoscitori.
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

def taglioPicchi(data, cmp_outlier):
    finestre=list()
    for i in cmp_outlier:
        tmp=data[(i-5):(i+5)] #l'intervallo di 10 campioni è stato scelto sperimentalmente guardando l'ampiezza dei picchi
        finestre.append(tmp)
    
    #disegno i tracciati dei picchi 
    Xvalue=np.arange(0,10)

    for i in range (len(cmp_outlier)):
        plt.plot(Xvalue,finestre[i])
        print(finestre[i])
    plt.show()
    
    return(finestre)

# %%
#cross-correlazione tra finestra con zero-padding e segnale 
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.signal as signal
from numpy.fft import rfft, irfft

def calcoloCCR(data, arrwnd):

#le due liste da confrontare devono avere stessa lunghezza

    for i in range (12):
   
        template=arrwnd[i].tolist()
    
    #Zero padding
        for i in range (10,len(data)):
            template.append(0)

    # Fast Fourier Transform (FFT)
        Data= rfft(data)
        movStdZcamp=pd.Series(data).rolling(len(data)).std()
   
    # Inverto il vettore template
        tempY = []
        while len(template) > 0:
            tempY.append(template.pop())
        movStdtempY=pd.Series(tempY).rolling(len(tempY)).std()
    
        Y = rfft(tempY)

    # Faccio la formula inversa della FFT
        CrossCorrelazione = irfft(Data*Y)
      
        x=np.arange(0,len(data))
        plt.plot(x,CrossCorrelazione)
        plt.xlabel("Campioni")
        plt.ylabel("CrossCorrelazione")
        line1=plt.plot(x,[3]*len(data),'r')
        plt.show()

# %%
#Analisi dati lungo Z
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dataZ=np.loadtxt("DataZ.npy")

cmp_outlierZ=individuaOutlier(dataZ,tc)
finestreZ=taglioPicchi(dataZ,cmp_outlierZ)
calcoloCCR(dataZ,finestreZ)
# Out:
# Outlier presenti ai secondi:
# [3.2, 9.8, 12.700000000000001, 15.0, 16.6, 18.5, 20.1, 21.6, 23.0, 24.5, 27.400000000000002, 29.1]
# I campioni outlier sono
# [32, 98, 127, 150, 166, 185, 201, 216, 230, 245, 274, 291]
# [ 0.08  0.13  0.11  0.19  0.31  1.5   0.66  0.68  0.88  1.03]
# [-0.04  0.28  0.05  0.1   0.28  1.47  0.97  0.82  0.74  0.55]
# [-0.12 -0.21 -0.22 -0.15  0.07  1.46  0.94  0.97  1.08  0.89]
# [-0.26 -0.24 -0.24 -0.24 -0.09  1.67  0.99  0.91  0.86  0.7 ]
# [-0.24 -0.23 -0.16  0.01  0.11  1.45  0.98  0.91  0.69  0.37]
# [-0.04 -0.01 -0.04 -0.08  0.06  1.52  0.92  0.58  0.21  0.09]
# [-0.06 -0.04 -0.03  0.02  0.71  1.22  1.03  0.78  0.53  0.34]
# [-0.17 -0.11 -0.03  0.06  0.24  1.28  0.93  0.75  0.69  0.58]
# [-0.18 -0.24 -0.22 -0.16  0.23  1.54  1.    0.96  0.82  0.74]
# [-0.2  -0.23 -0.23 -0.18  0.23  1.51  0.86  0.83  1.03  1.04]
# [-0.14 -0.13 -0.06 -0.02  0.3   1.6   0.97  0.95  0.91  0.83]
# [-0.14 -0.11 -0.1   0.04  0.29  1.61  1.    0.81  0.57  0.3 ]

# %%
#Analisi dati lungo Y
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dataY=np.loadtxt("DataY.npy")


cmp_outlierY=individuaOutlier(dataY,tc)
finestreY=taglioPicchi(dataY,cmp_outlierY)
calcoloCCR(dataZ,finestreY)
# Out:
# Outlier presenti ai secondi:
# [3.0, 3.7, 4.2, 4.6000000000000005, 4.800000000000001, 5.2, 8.700000000000001, 9.200000000000001, 15.0, 16.6, 17.0, 17.1, 20.200000000000003, 20.3, 22.3, 24.400000000000002, 24.5, 25.200000000000003, 27.5, 27.6, 28.3, 28.400000000000002, 28.700000000000003, 28.8, 28.900000000000002]
